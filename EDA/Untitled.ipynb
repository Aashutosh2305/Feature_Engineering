# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/ashutoshmishra/Documents/tensorflow/linear regression/titanic data.csv")

# %%
df.head(10)
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0         0    male  22.0                   1      0   7.2500   Third
# 1         1  female  38.0                   1      0  71.2833   First
# 2         1  female  26.0                   0      0   7.9250   Third
# 3         1  female  35.0                   1      0  53.1000   First
# 4         0    male  28.0                   0      0   8.4583   Third
# 5         0    male   2.0                   3      1  21.0750   Third
# 6         1  female  27.0                   0      2  11.1333   Third
# 7         1  female  14.0                   1      0  30.0708  Second
# 8         1  female   4.0                   1      1  16.7000   Third
# 9         0    male  20.0                   0      0   8.0500   Third
#
#       deck  embark_town alone
# 0  unknown  Southampton     n
# 1        C    Cherbourg     n
# 2  unknown  Southampton     y
# 3        C  Southampton     n
# 4  unknown   Queenstown     y
# 5  unknown  Southampton     n
# 6  unknown  Southampton     n
# 7  unknown    Cherbourg     n
# 8        G  Southampton     n
# 9  unknown  Southampton     y

# %%
#sns.countplot(df["survived"])
df['survived'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df["class"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df["embark_town"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df["sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df["survived"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='survived'>

# %%
df["class"].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='class'>

# %%
plt.hist(df["age"],bins=50)
# Out:
# (array([ 12.,   4.,  10.,   5.,   0.,   7.,   4.,   0.,  10.,  11.,  27.,
#          17.,  23.,  18.,  34.,  27.,  12., 169.,  18.,  27.,  24.,  17.,
#          23.,   7.,  20.,   7.,   8.,  16.,   3.,  15.,   6.,  14.,   4.,
#           1.,   2.,   2.,   5.,   4.,   3.,   3.,   2.,   1.,   0.,   1.,
#           3.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 0.75 ,  2.335,  3.92 ,  5.505,  7.09 ,  8.675, 10.26 , 11.845,
#         13.43 , 15.015, 16.6  , 18.185, 19.77 , 21.355, 22.94 , 24.525,
#         26.11 , 27.695, 29.28 , 30.865, 32.45 , 34.035, 35.62 , 37.205,
#         38.79 , 40.375, 41.96 , 43.545, 45.13 , 46.715, 48.3  , 49.885,
#         51.47 , 53.055, 54.64 , 56.225, 57.81 , 59.395, 60.98 , 62.565,
#         64.15 , 65.735, 67.32 , 68.905, 70.49 , 72.075, 73.66 , 75.245,
#         76.83 , 78.415, 80.   ]),
#  <BarContainer object of 50 artists>)

# %%
sns.displot(df["age"],kde=True)

# %%
sns.boxplot(df["fare"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["age"])
# Out:
# <Axes: >

# %%
df['age'].min()
# Out:
# 0.75

# %%
df['age'].max()
# Out:
# 80.0

# %%
df['age'].mean()
# Out:
# 29.631307814992027

# %%
df['age'].skew()
# Out:
# 0.5551865555552414
